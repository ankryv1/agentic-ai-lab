# %% [markdown]
# Parallel Workflow

# %%
from langgraph.graph import StateGraph, START , END

# %%
from typing import TypedDict
class BatsmanState(TypedDict):
    runs: int
    wickets:int
    fours: int
    sixes: int
    balls: int

    sr: float
    bpb: float
    boundary_percent: float

# %%
def calculate_sr(state: BatsmanState)  :
    runs = state['runs']
    wicket = state['wickets']
    balls = state['balls']

    sr = (runs/balls)*100
    return {'sr': sr}

# %%
def calculate_bpb(state: BatsmanState) :
    bpb = state['balls']/(state['fours']+ state['sixes'])
    return {'bpb':bpb}

# %%
def calculate_boundary_percent(state: BatsmanState)  :
    boundary_percentage= ((state['fours']*4)+ (state['sixes']*6))/state['runs']
    return {'boundary_percent':boundary_percentage}

# %%
def summary(state: BatsmanState) :
    summary =  f""" Strike rate is {state['sr']},
    Balls per boundary is {state['bpb']},
    Boundary percentage is {state['boundary_percent']}
    """
    state['summary'] = summary
    return state

# %%
graph = StateGraph(BatsmanState)

graph.add_node("calculate_sr", calculate_sr)

graph.add_node("calculate_bpb", calculate_bpb)

graph.add_node("calculate_boundary_percent", calculate_boundary_percent)

graph.add_node("summary", summary)

# %%
graph.add_edge(START, "calculate_sr")
graph.add_edge(START, "calculate_bpb")
graph.add_edge(START, "calculate_boundary_percent")

graph.add_edge('calculate_sr', "summary")
graph.add_edge('calculate_bpb', "summary")
graph.add_edge('calculate_boundary_percent', "summary")

graph.add_edge("summary", END)

workflow=graph.compile()

initial_state= {'runs': 200, 'wickets': 5, 'fours':10, 'sixes': 12}

final_state =workflow.invoke(initial_state)
print(final_state)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 15
#      11 workflow=graph.compile()
#      12
#      13 initial_state= {'runs': 200, 'wickets': 5, 'fours':10, 'sixes': 12}
#      14
# ---> 15 final_state =workflow.invoke(initial_state)
#      16 print(final_state)
#
# File c:\Users\ANKIT\OneDrive\Desktop\python\AgenticX\.venv\Lib\site-packages\langgraph\pregel\main.py:3928, in Pregel.invoke(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, control, version, **kwargs)
#    3925             chunks.append(chunk)
#    3926 else:
#    3927     # v1: collect interrupts from updates stream
# -> 3928     for chunk in self.stream(
#    3929         input,
#    3930         config,
#    3931         context=context,
#    3932         stream_mode=(
#    3933             ["updates", "values"] if stream_mode == "values" else stream_mode
#    3934         ),
#    3935         print_mode=print_mode,
#    3936         output_keys=output_keys,
#    3937         interrupt_before=interrupt_before,
#    3938         interrupt_after=interrupt_after,
#    3939         durability=durability,
#    3940         control=control,
#    3941         **kwargs,
#    3942     ):
#    3943         if stream_mode == "values":
#    3944             if len(chunk) == 2:
#
# File c:\Users\ANKIT\OneDrive\Desktop\python\AgenticX\.venv\Lib\site-packages\langgraph\pregel\main.py:2982, in Pregel.stream(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, control, subgraphs, debug, version, **kwargs)
#    2980 for task in loop.match_cached_writes():
#    2981     loop.output_writes(task.id, task.writes, cached=True)
# -> 2982 for _ in runner.tick(
#    2983     [t for t in loop.tasks.values() if not t.writes],
#    2984     timeout=self.step_timeout,
#    2985     get_waiter=get_waiter,
#    2986     schedule_task=loop.accept_push,
#    2987 ):
#    2988     # emit output
#    2989     yield from _output(
#    2990         stream_mode,
#    2991         print_mode,
#    (...)   2997         _state_mapper,
#    2998     )
#    2999 loop.after_tick()
#
# File c:\Users\ANKIT\OneDrive\Desktop\python\AgenticX\.venv\Lib\site-packages\langgraph\pregel\_runner.py:344, in PregelRunner.tick(self, tasks, reraise, timeout, retry_policy, get_waiter, schedule_task)
#     342 # panic on failure or timeout
#     343 try:
# --> 344     _panic_or_proceed(
#     345         futures.done.union(f for f, t in futures.items() if t is not None),
#     346         panic=reraise,
#     347         handled_exception_ids=self._handled_exception_ids,
#     348         handled_futures=handled_futures,
#     349     )
#     350 except Exception as exc:
#     351     if tb := exc.__traceback__:
#
# File c:\Users\ANKIT\OneDrive\Desktop\python\AgenticX\.venv\Lib\site-packages\langgraph\pregel\_runner.py:687, in _panic_or_proceed(futs, timeout_exc_cls, panic, handled_exception_ids, handled_futures)
#     685                 interrupts.append(exc)
#     686             elif fut not in SKIP_RERAISE_SET:
# --> 687                 raise exc
#     688 # raise combined interrupts
#     689 if interrupts:
#
# File c:\Users\ANKIT\OneDrive\Desktop\python\AgenticX\.venv\Lib\site-packages\langgraph\pregel\_executor.py:80, in BackgroundExecutor.done(self, task)
#      78 """Remove the task from the tasks dict when it's done."""
#      79 try:
# ---> 80     task.result()
#      81 except GraphBubbleUp:
#      82     # This exception is an interruption signal, not an error
#      83     # so we don't want to re-raise it on exit
#      84     self.tasks.pop(task)
#
# File ~\AppData\Local\Python\pythoncore-3.12-64\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~\AppData\Local\Python\pythoncore-3.12-64\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~\AppData\Local\Python\pythoncore-3.12-64\Lib\concurrent\futures\thread.py:59, in _WorkItem.run(self)
#      56     return
#      58 try:
# ---> 59     result = self.fn(*self.args, **self.kwargs)
#      60 except BaseException as exc:
#      61     self.future.set_exception(exc)
#
# File c:\Users\ANKIT\OneDrive\Desktop\python\AgenticX\.venv\Lib\site-packages\langgraph\pregel\_retry.py:617, in run_with_retry(task, retry_policy, configurable)
#     615     task.writes.clear()
#     616     # run the task
# --> 617     return task.proc.invoke(task.input, config)
#     618 except ParentCommand as exc:
#     619     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File c:\Users\ANKIT\OneDrive\Desktop\python\AgenticX\.venv\Lib\site-packages\langgraph\_internal\_runnable.py:684, in RunnableSeq.invoke(self, input, config, **kwargs)
#     682     # run in context
#     683     with set_config_context(config, run) as context:
# --> 684         input = context.run(step.invoke, input, config, **kwargs)
#     685 else:
#     686     input = step.invoke(input, config)
#
# File c:\Users\ANKIT\OneDrive\Desktop\python\AgenticX\.venv\Lib\site-packages\langgraph\_internal\_runnable.py:426, in RunnableCallable.invoke(self, input, config, **kwargs)
#     424         run_manager.on_chain_end(ret)
#     425 else:
# --> 426     ret = self.func(*args, **kwargs)
#     427 if self.recurse and isinstance(ret, Runnable):
#     428     return ret.invoke(input, config)
#
# Cell In[3], line 4, in calculate_sr(state)
#       1 def calculate_sr(state: BatsmanState)  :
#       2     runs = state['runs']
#       3     wicket = state['wickets']
# ----> 4     balls = state['balls']
#       5
#       6     sr = (runs/balls)*100
#       7     return {'sr': sr}
#
# KeyError: 'balls'
# During task with name 'calculate_sr' and id '721eb658-4458-b8d9-6d9c-dd14bf0ca3b3'
